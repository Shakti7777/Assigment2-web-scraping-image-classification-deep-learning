# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
import shutil

# %%
url = "https://www.amazon.in/b/ref=s9_acss_bw_cg_WWDTIMPC_2a1_w?node=17186599031&pf_rd_m=A1K21FY43GMZF8&pf_rd_s=merchandised-search-5&pf_rd_r=1C91CK7XYZXAX26P40VY&pf_rd_t=101&pf_rd_p=79601a8b-7d7e-4e08-84fe-e82957496171&pf_rd_i=1968256031"




response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

aas = soup.find_all("img", class_='s-access-image cfMarker')

# %%
aas
# Out:
# [<img alt="RANI SAAHIBA Cotton with Blouse Piece Saree" class="s-access-image cfMarker" data-search-image-load="" height="260" src="https://images-eu.ssl-images-amazon.com/images/I/41JSVtrgi7L._AC_UL260_SR200,260_.jpg" srcset="https://images-eu.ssl-images-amazon.com/images/I/41JSVtrgi7L._AC_UL260_SR200,260_.jpg 1x, https://images-eu.ssl-images-amazon.com/images/I/41JSVtrgi7L._AC_UL390_SR300,390_QL65_.jpg 1.5x, https://images-eu.ssl-images-amazon.com/images/I/41JSVtrgi7L._AC_UL500_SR385,500_QL65_.jpg 1.9230x" width="200"/>,
# ...

# %%
def download_image(image):
    response = requests.get(image[0], stream=True)
    realname = ''.join(e for e in image[1] if e.isalnum())
    
    file = open("C://images//bs//{}.jpg".format(realname), 'wb')
    
    response.raw.decode_content = True
    shutil.copyfileobj(response.raw, file)
    del response
